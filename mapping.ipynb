# %%
from pathlib import Path
import os
import zutils
from allensdk.core.reference_space_cache import ReferenceSpaceCache

# %%
"""
Load the Data
"""
# Data Folder
dataDir = 'C:\\Users\\zachl\\OneDrive\\BU_YEAR1\\Economo_Rotation\\data\\'

# File Parameters
sub = ['484675']
date = ['20210318',  '20210319']

# LOAD DATA
data = zutils.load_data(dataDir, sub, date)

sub1=data[0]
# Out:
# Loading data for sub-['484675']:['20210318', '20210319'] from
# Data directory: C:\Users\zachl\OneDrive\BU_YEAR1\Economo_Rotation\data\
# ['sub-484675_ses-20210318T122039_behavior+ecephys+ogen.nwb'
#  'sub-484675_ses-20210319T121514_behavior+ecephys+ogen.nwb']

# %%
df = zutils.saveCCFCoordsAndRegion(sub1,'./','./',sub[0],date[0])
# Out:
# c:\Users\zachl\OneDrive\BU_YEAR1\Economo_Rotation\Susu_Data_Analysis\EphysDataAnalysis\zutils.py:57: RuntimeWarning: invalid value encountered in cast
#   x = electrodes.x.data[:].astype(int) # ML in Allen CCF
# c:\Users\zachl\OneDrive\BU_YEAR1\Economo_Rotation\Susu_Data_Analysis\EphysDataAnalysis\zutils.py:58: RuntimeWarning: invalid value encountered in cast
#   y = electrodes.y.data[:].astype(int) # DV in Allen CCF
# c:\Users\zachl\OneDrive\BU_YEAR1\Economo_Rotation\Susu_Data_Analysis\EphysDataAnalysis\zutils.py:59: RuntimeWarning: invalid value encountered in cast
#   z = electrodes.z.data[:].astype(int) # AP in Allen CCF
# 100%|██████████| 1319/1319 [00:00<00:00, 16499.86it/s]

# %%
import numpy as np
df
# Out:
#       unit     x     y     z  electrodes   id  \
# 0        0  9700  5280  7540           0  952
# 1        1  9700  5280  7540           1  952
# 2        2  9700  5240  7520           7  952
# 3        3  9700  5220  7520           9  952
# 4        4  9700  5240  7520           7  952
# ...    ...   ...   ...   ...         ...  ...
# 1314   378  8520  4500  5360        1498  672
# 1315   379  9140  4900  5240        1290  314
# 1316   380  9140  4880  5240        1292  579
# 1317   381  8700  4500  5320        1420  672
# 1318   382  8700  4480  5320        1425  672
#
#                                                 region
# 0                    Endopiriform nucleus, dorsal part
# 1                    Endopiriform nucleus, dorsal part
# 2                    Endopiriform nucleus, dorsal part
# 3                    Endopiriform nucleus, dorsal part
# 4                    Endopiriform nucleus, dorsal part
# ...                                                ...
# 1314                                      Caudoputamen
# 1315  Agranular insular area, posterior part, layer 6a
# 1316                                  external capsule
# 1317                                      Caudoputamen
# 1318                                      Caudoputamen
#
# [1319 rows x 7 columns]
